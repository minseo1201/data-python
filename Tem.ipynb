# %% [markdown]
# <a href="https://colab.research.google.com/github/minseo1201/data-python/blob/main/Tem.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install paho-mqtt
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.9/66.9 kB 829.1 kB/s eta 0:00:00
# ...

# %%
import paho.mqtt.client as mqtt

def on_connect(client, userdata, flags, reason_code, properties):
    print(f"Connected with result code {reason_code}")
    client.subscribe("connectware/indoor/data/#")

def on_message(client, userdata, msg):
    print(msg.topic, msg.payload.decode('utf8'))

client = mqtt.Client(mqtt.CallbackAPIVersion.VERSION2)
client.on_connect = on_connect
client.on_message = on_message

client.connect("damoa.io", 1883, 60)
client.loop_forever()
# Out:
# Connected with result code Success
# connectware/indoor/data/1501 {"dust":"52,66","co2":"440","bme680":"21.43,21.90,801072,101031,24.51","time":"2024-04-07 03:12:01", "serial":215175, "ip":"203.255.190.49"}
# connectware/indoor/data/1502 {"dust":"57,69","co2":"606","bme680":"23.02,19.62,1626911,101078,20.58","time":"2024-04-07 03:12:02", "serial":210632, "ip":"203.255.190.49"}
# connectware/indoor/data/1503 {"dust":"50,71","co2":"448","bme680":"22.33,21.06,665666,101036,24.09","time":"2024-04-07 03:12:01", "serial":210625, "ip":"203.255.190.49"}
# connectware/indoor/data/1501 {"dust":"54,67","co2":"440","bme680":"21.43,21.90,809753,101031,24.51","time":"2024-04-07 03:12:02", "serial":215176, "ip":"203.255.190.49"}
# connectware/indoor/data/1502 {"dust":"55,68","co2":"606","bme680":"23.02,19.63,1629901,101078,20.58","time":"2024-04-07 03:12:03", "serial":210633, "ip":"203.255.190.49"}
# ...
